# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('ihdp.csv')

# %%
data.head()
# Out:
#          x1        x2        x3        x4  ...    t        yf       ycf       ite
# 0  1.397395  0.996346 -1.105624 -0.879606  ...  1.0  4.771232 -0.298509  4.657928
# 1  0.269033  0.196818  0.383828  0.161703  ...  0.0  2.956273  5.783770  3.428604
# 2  1.051537  1.795874 -1.105624  0.161703  ...  0.0  4.164164  7.055789  3.658195
# 3  0.662446  0.196818 -0.733261 -0.879606  ...  1.0  6.172307  1.379697  4.585505
# 4  0.856992  1.795874  0.011465 -0.879606  ...  1.0  7.834469  2.747986  4.265591
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (747, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      747 non-null    float64
#  1   x2      747 non-null    float64
#  2   x3      747 non-null    float64
#  3   x4      747 non-null    float64
#  4   x5      747 non-null    float64
#  5   x6      747 non-null    float64
#  6   x7      747 non-null    float64
#  7   x8      747 non-null    float64
#  8   x9      747 non-null    float64
#  9   x10     747 non-null    float64
#  10  x11     747 non-null    float64
#  11  x12     747 non-null    float64
#  12  x13     747 non-null    float64
#  13  x14     747 non-null    float64
#  14  x15     747 non-null    float64
#  15  x16     747 non-null    float64
#  16  x17     747 non-null    float64
#  17  x18     747 non-null    float64
#  18  x19     747 non-null    float64
#  19  x20     747 non-null    float64
# ...

# %%
data.describe()
# Out:
#                  x1            x2  ...         ycf         ite
# count  7.470000e+02  7.470000e+02  ...  747.000000  747.000000
# mean   3.626431e-17  2.348263e-17  ...    5.696107    4.016067
# std    1.000000e+00  1.000000e+00  ...    1.980121    0.859736
# min   -2.731287e+00 -3.800823e+00  ...   -1.037628   -1.866989
# 25%   -6.669461e-01 -6.027100e-01  ...    5.053598    3.775936
# 50%    1.652752e-01  1.968181e-01  ...    6.209686    4.304433
# 75%    8.137593e-01  5.965822e-01  ...    6.948922    4.569454
# max    1.505476e+00  2.595403e+00  ...   10.171004    4.670125
#
# [8 rows x 29 columns]

# %%
data.dtypes
# Out:
# x1     float64
# x2     float64
# x3     float64
# x4     float64
# x5     float64
# x6     float64
# x7     float64
# x8     float64
# x9     float64
# x10    float64
# x11    float64
# x12    float64
# x13    float64
# x14    float64
# x15    float64
# x16    float64
# x17    float64
# x18    float64
# x19    float64
# x20    float64
# x21    float64
# x22    float64
# x23    float64
# x24    float64
# x25    float64
# t      float64
# yf     float64
# ycf    float64
# ite    float64
# dtype: object

# %%
data.columns
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11',
#        'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21',
#        'x22', 'x23', 'x24', 'x25', 't', 'yf', 'ycf', 'ite'],
#       dtype='object')

# %%
categorical_columns= ['x7', 'x8', 'x9', 'x10', 'x11',
       'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21',
       'x22', 'x23', 'x24', 'x25', 't']

plt.figure(figsize=(19,15))
for i,column in zip(range(1, 21),categorical_columns):
    plt.subplot(5, 4, i)
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

    sns.countplot(data[column])
    plt.title('Countplot of {}'.format(column))

plt.savefig('countplot_IHDP.png')

# %%
num_columns= ['x1', 'x2', 'x3', 'x4', 'x5', 'x6']

plt.figure(figsize=(16,19))
def plot(col):
    sns.displot(data, x=col,binwidth=1)
    plt.title('Distribution plot of {}'.format(col))
    plt.show()
    plt.savefig('Distribution plot of {}'.format(col))   

for col in num_columns:
    plot(col)

# %%
import seaborn as sns
corrmat=data.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(25,18))
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
plt.savefig('correlation_IHDP.png')

# %%
#Checking for the missing values in the dataset
data.isna().sum()
# Out:
# x1     0
# x2     0
# x3     0
# x4     0
# x5     0
# x6     0
# x7     0
# x8     0
# x9     0
# x10    0
# x11    0
# x12    0
# x13    0
# x14    0
# x15    0
# x16    0
# x17    0
# x18    0
# x19    0
# x20    0
# x21    0
# x22    0
# x23    0
# x24    0
# x25    0
# t      0
# yf     0
# ycf    0
# ite    0
# dtype: int64

# %%
# Checking for the duplicate values in the dataset and removing it
data.duplicated().sum()
data=data.drop_duplicates()
print(data.shape)
# Out:
# (747, 29)

# %%
# Checking for the outliers in the dataset and removing it

def outliers_removing(data):
    for col in num_columns:
        if (((data[col].dtype)=='float64') | ((data[col].dtype)=='float64')):
            percentiles = data[col].quantile([0.01,0.99]).values
            data[col][data[col] <= percentiles[0]] = percentiles[0]
            data[col][data[col] >= percentiles[1]] = percentiles[1]
        else:
            data[col]=data[col]
    return data

data=outliers_removing(data)
print(data.shape)
# Out:
# (747, 29)

# %% [markdown]
# There are no outliers present in the dataset.

# %%
features = data.loc[:, data.columns != 'yf']
target= data['yf']

# %% [markdown]
# # Finding the most important features in the dataset

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100)
model.fit(features,target)
# Out:
# RandomForestRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.02838519 0.01270068 0.01123805 0.00462931 0.02385001 0.02109717
#  0.00410501 0.0023841  0.00262409 0.00212971 0.00275706 0.00275701
#  0.00278482 0.00149059 0.00111846 0.00170691 0.00305506 0.00176704
#  0.00231767 0.00288336 0.00187275 0.00196816 0.00146605 0.00186663
#  0.00384504 0.51463923 0.037916   0.30064485]

# %%
feature_importance=pd.Series(model.feature_importances_,index=features.columns)
feature_importance.nlargest(10).plot(kind='barh')
plt.show()
plt.savefig('feature_importance_IHDP.png')
